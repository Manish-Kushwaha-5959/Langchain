# %%
from langchain_huggingface import HuggingFaceEmbeddings, ChatHuggingFace, HuggingFaceEndpoint
from langchain.vectorstores import FAISS
from langchain.schema import Document
from langchain.retrievers.multi_query import MultiQueryRetriever
from dotenv import load_dotenv

# %%
# Creating embedding model
import os
os.environ['HF_HOME'] = 'D:/huggingface_cache'

embeddings = HuggingFaceEmbeddings(model = "sentence-transformers/all-MiniLM-L6-v2")

# %%
load_dotenv()

llm = HuggingFaceEndpoint(
    repo_id="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
    task="text-generation"
)

model = ChatHuggingFace(llm=llm)

# %%
documents = [
    Document(page_content="Artificial Intelligence (AI) is the simulation of human intelligence in machines."),
    Document(page_content="Machine learning is a subset of AI that enables systems to learn from data."),
    Document(page_content="Deep learning uses neural networks with many layers."),
    Document(page_content="AI is widely used in healthcare, finance, and autonomous vehicles."),
    Document(page_content="Natural Language Processing helps machines understand human language."),
    Document(page_content="Computer vision enables machines to interpret visual data."),
]

# %%
retriever = MultiQueryRetriever.from_llm(
    retriever=vectorstore.as_retriever(),
    llm=model
)

# %%
query = "Explain AI applications"

docs = retriever.get_relevant_documents(query)

for i, doc in enumerate(docs):
    print(f"\nResult {i+1}:")
    print(doc.page_content)
