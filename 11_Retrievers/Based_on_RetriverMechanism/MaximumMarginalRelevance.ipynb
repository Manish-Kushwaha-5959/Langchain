# %%
# Importing necessary libraires
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain_core.documents import Document

# %%
# Creating embedding model
import os
os.environ['HF_HOME'] = 'D:/huggingface_cache'

embeddings = HuggingFaceEmbeddings(model = "sentence-transformers/all-MiniLM-L6-v2")

# %%
docs = [
    Document(page_content="Python is a popular programming language for data science."),
    Document(page_content="Python is widely used for machine learning and AI."),
    Document(page_content="Machine learning enables systems to learn from data."),
    Document(page_content="Deep learning is a subset of machine learning."),
    Document(page_content="Artificial intelligence is transforming industries."),
    Document(page_content="AI is used in healthcare, finance, and automation."),
]

# %%
retriever = vectorstore.as_retriever(
    search_type="mmr",   # 🔥 Key part: Maximum Marginal Relevance
    search_kwargs={
        "k": 3,          # number of final results
        "fetch_k": 5,    # number of initial candidates
        "lambda_mult": 0.7  # balance between relevance & diversity
    }
)

# %%
query = "What is AI and machine learning?"

results = retriever.get_relevant_documents(query)

for i, doc in enumerate(results):
    print(f"\nResult {i+1}:")
    print(doc.page_content)
